# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:/FoodBalanceSheets_E_Africa_NOFLAG.CSV', encoding='latin-1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Area Code, Area, Item Code, Item, Element Code, Element, Unit, Y2014, Y2015, Y2016, Y2017, Y2018]
# Index: []

# %%
df.isnull()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# ...          ...    ...        ...    ...           ...      ...    ...
# 60938      False  False      False  False         False    False  False
# 60939      False  False      False  False         False    False  False
# 60940      False  False      False  False         False    False  False
# 60941      False  False      False  False         False    False  False
# 60942      False  False      False  False         False    False  False
#
#        Y2014  Y2015  Y2016  Y2017  Y2018
# 0      False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.head(2)
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
# 1          4  Algeria       2501  Population          5301
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity   1000 tonnes      0.0      0.0      0.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0

# %%
df['Item'].value_counts()
# Out:
# Milk - Excluding Butter     1262
# Eggs                        1142
# Miscellaneous                911
# Cereals - Excluding Beer     714
# Oilcrops                     706
#                             ...
# Grand Total                  135
# Animal Products              135
# Vegetal Products             135
# Sugar non-centrifugal        121
# Population                    90
# Name: Item, Length: 119, dtype: int64

# %%
df[(df['Item'] == 'Animal Products')]
# Out:
#        Area Code      Area  Item Code             Item  Element Code  \
# 8              4   Algeria       2941  Animal Products           664
# 9              4   Algeria       2941  Animal Products           674
# 10             4   Algeria       2941  Animal Products           684
# 1321           7    Angola       2941  Animal Products           664
# 1322           7    Angola       2941  Animal Products           674
# ...          ...       ...        ...              ...           ...
# 58108        251    Zambia       2941  Animal Products           674
# 58109        251    Zambia       2941  Animal Products           684
# 59558        181  Zimbabwe       2941  Animal Products           664
# 59559        181  Zimbabwe       2941  Animal Products           674
# 59560        181  Zimbabwe       2941  Animal Products           684
#
#                                       Element             Unit   Y2014  \
# ...
